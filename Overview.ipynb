# %%
from matplotlib import image
import matplotlib.pyplot as plt

# %%
img_1 = image.imread('Overview_AFE_DC.png')
fig = plt.figure(figsize = (100, 50))
 
plt.imshow(img_1)
plt.show()

# %%
img_2 = image.imread('Overview_algo.png')
fig = plt.figure(figsize = (100, 50))
 
plt.imshow(img_1)
plt.show()
