# %%
import audioread
import numpy as np

import matplotlib.pyplot as plt

audio=[]

with audioread.audio_open("./audio/good_morning.wav") as file:
    print(file.channels, file.samplerate, file.duration)
    for buffer in file:
        audio.append(np.frombuffer(buffer,"Int16"))
# Out:
# 1 24000 1.104
# C:\Users\Christopher Gomes\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   # This is added back by InteractiveShellApp.init_path()

# %%
plt.title("Audio Wave Form")
plt.xlabel("Time in seconds")
plt.ylabel("Amplitude")

time=np.linspace(0,len(audio[:-1])/file.samplerate,num=len(audio[:-1]))*1000
plt.plot(time,audio[:-1])

plt.rcParams["figure.figsize"] = (50,40)
plt.show()

# %%
len(audio)
# Out:
# 26
